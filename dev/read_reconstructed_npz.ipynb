# %%
import numpy
import matplotlib.pyplot as plt

# %%
reconstructed = numpy.load("../data/hotrod_phantom_data_180x180_reconstructed.npz")['reconstructed']
fig, ax = plt.subplots(figsize=(16, 10))
ax.imshow(numpy.reshape(reconstructed,(180,180)), cmap='gray')
