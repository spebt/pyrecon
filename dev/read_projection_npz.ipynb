# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
projection = np.load('../data/hotrod_phantom_data_180x180_projection.npz')

# %%
fig, ax = plt.subplots(1, 1, figsize=(26, 12))
fig.colorbar(ax.imshow(projection['projection'], cmap='gray', aspect='equal',origin='lower'))
